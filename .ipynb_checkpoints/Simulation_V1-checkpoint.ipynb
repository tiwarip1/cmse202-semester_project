# %%
from classes import *
from ivisual import *
import numpy as np
from PIL import ImageGrab

# %%
scene = canvas(title='Ideal Gas')
canvas.autoscale('True')
s = system()
boxsize = s.boxsize
b = box(pos=((boxsize[1]+boxsize[0])/2.,
                 (boxsize[3]+boxsize[2])/2.,
                 (boxsize[5]+boxsize[4])/2.),
            size=(boxsize[1]-boxsize[0],
                  boxsize[3]-boxsize[2],
                  boxsize[5]-boxsize[4]),
            color=color.white,
            opacity=0.1)

iteration = 1000
for i in range(iteration): # 10 seconds
# while True:
    rate(100)
    s.update()
    im = ImageGrab.grab((0,0,500,500))
    fname = './images/test' + str(i) + '.png'
    im.save(fname)
# Out:
# <div id="scene2"><div id="glowscript" class="glowscript"></div></div>
# (MainThread) STREAM b'IHDR' 16 13
# (MainThread) STREAM b'iCCP' 41 3111
# (MainThread) iCCP profile name b'ICC Profile'
# (MainThread) Compression method 0
# (MainThread) STREAM b'pHYs' 3164 9
# (MainThread) STREAM b'iTXt' 3185 415
# (MainThread) STREAM b'iDOT' 3612 28
# (MainThread) b'iDOT' 3612 28 (unknown)
# (MainThread) STREAM b'IDAT' 3652 16384
# (MainThread) STREAM b'IHDR' 16 13
# (MainThread) STREAM b'iCCP' 41 3111
# (MainThread) iCCP profile name b'ICC Profile'
# (MainThread) Compression method 0
# (MainThread) STREAM b'pHYs' 3164 9
# (MainThread) STREAM b'iTXt' 3185 415
# (MainThread) STREAM b'iDOT' 3612 28
# (MainThread) b'iDOT' 3612 28 (unknown)
# (MainThread) STREAM b'IDAT' 3652 16384
# (MainThread) STREAM b'IHDR' 16 13
# (MainThread) STREAM b'iCCP' 41 3111
# (MainThread) iCCP profile name b'ICC Profile'
# (MainThread) Compression method 0
# (MainThread) STREAM b'pHYs' 3164 9
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# (MainThread) backend module://ipykernel.pylab.backend_inline version unknown

# %%
plt.plot(np.arange(i), s.pressure_arr)
# Out:
# (MainThread) findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0 to DejaVu Sans ('/Users/erikalustig/anaconda/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans.ttf') with score of 0.050000

# %%
len(s.energy_arr)
# Out:
# 1000
